# %%
import sys
sys.path.append("C:\\Users\\Hudson\\Google Drive\\School\\Classes\\Cogs-181\\Final\\Convolutional-GAN")

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import glob
from PIL import Image
from glob import glob
import scipy.signal

# %%
image_list = map(lambda x: x.resize((64,64)),
                 map(Image.open, glob("../data/img_align_celeba/img_align_celeba/200*.jpg")))
image_array = np.array(list(map(np.asarray, image_list)))

# %%
x = image_array.transpose(0, 3, 1, 2)

# %%
x.shape

# %%
from lib.utils import rescale

# %%
x = rescale(x).astype("float32")

# %%
import models.WGANsmall as WGANs
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5110)

# %%
wgan = WGANs.WGANsmall()

# %%
wgan.train(x, iters = 200)

# %%
wgan.plot()

# %%
from lib.utils import viewSample

# %%
viewSample(wgan.sample(3))
